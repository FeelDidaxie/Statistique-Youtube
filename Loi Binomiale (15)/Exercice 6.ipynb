# %% [markdown]
# <center> <h1 style="background-color:#252549; padding: 4px; color:white" >Modélisation des Réclamations d'Assurance</h1>
#
# <br>
#
# <center><img
# src="https://img.freepik.com/free-vector/auto-insurance-template-social-media-post_53876-119138.jpg"
#              style="width:40%;height:20%;">
# </center>
#
#
# <div class="list-group" id="list-tab" role="tablist">
#
#   <h3 class="list-group-item list-group-item-action active" style="background-color:#252549; color:white" data-toggle="list"  role="tab" aria-controls="home">Sommaire</h3>
#   <a class="list-group-item list-group-item-action" data-toggle="list" href="#introduction" role="tab" aria-controls="profile" style="color:#252549">Introduction<span class="badge badge-primary badge-pill" style="background-color:#252549; color:white">1</span></a>
#   <a id="section2" class="list-group-item list-group-item-action" data-toggle="list" href="#question1" role="tab" aria-controls="messages" style="color:#333F4F">Question n°01<span class="badge badge-primary badge-pill" style="background-color:#252549; color:white">2</span></a>
#   <a id="section2" class="list-group-item list-group-item-action" data-toggle="list" href="#question2" role="tab" aria-controls="messages" style="color:#252549">Question n°02<span class="badge badge-primary badge-pill" style="background-color:#252549; color:white">3</span></a>
#   <a id="section2" class="list-group-item list-group-item-action" data-toggle="list" href="#question3" role="tab" aria-controls="messages" style="color:#252549">Question n°03<span class="badge badge-primary badge-pill" style="background-color:#252549; color:white">4</span></a>
#   <a id="section2" class="list-group-item list-group-item-action" data-toggle="list" href="#question4" role="tab" aria-controls="messages" style="color:#252549">Question n°04<span class="badge badge-primary badge-pill" style="background-color:#252549; color:white">5</span></a>
#   <a id="section2" class="list-group-item list-group-item-action" data-toggle="list" href="#question5" role="tab" aria-controls="messages" style="color:#252549">Question n°05<span class="badge badge-primary badge-pill" style="background-color:#252549; color:white">6</span></a>
#     </div>

# %% [markdown]
# <a id='introduction'></a>
# # <div style=" background-color:#252549; color:white; padding: 12px; line-height: 1.5;">1. | Introduction</div>

# %% [markdown]
# ## <div style=" background-color: #4A4A90; color:white; padding: 10px; line-height: 1.5;"> Énoncé
# </div>
# <div style="font-family: Segoe UI; line-height: 2; color: #000000; text-align: justify">
#
#    👉 Une compagnie d'assurance automobile reçoit en moyenne <span style="background-color: #D3D3E9; color: #000000;"><b>1000 demandes de remboursement</b></span> chaque mois pour les sinistres automobiles. La probabilité qu'une demande de remboursement soit acceptée en raison d'un accident est de <span style="background-color: #D3D3E9; color: #000000;"><b>0.25</b></span>. En cas de sinistre accepté, <span style="background-color: #D3D3E9; color: #000000;"><b>la compagnie rembourse en moyenne 3000 €</b></span>. On suppose que chaque demande de remboursement est <span style="background-color: #D3D3E9; color: #000000;"><b>indépendante des autres</b></span> et suit une distribution binaire (binomiale) avec une probabilité d'acceptation de 0.25.
# </div>

# %% [markdown]
# ## <div style=" background-color: #4A4A90; color:white; padding: 10px; line-height: 1.5;"> Importer les bibliothèques 📚
# </div>

# %%
# Importer la fonction "comb" depuis le module math.

from math import comb

# %% [markdown]
# <div style="font-family: Segoe UI; line-height: 2; color: #000000; text-align: justify">
#
#    <span style="background-color: #D3D3E9; color: #000000;"><b>"Comb"</b></span> est une fonction pour calculer <span style="background-color: #D3D3E9; color: #000000;"><b>le coefficient binomial.</b></span>
# </div>

# %% [markdown]
# $$ C(n, k) = \frac{n!}{k!(n-k)!} $$

# %%
# Le nombre de combinaisons avec 5 tirages et avoir exactement 2 éléments.

comb(5, 2)
# Out:
# 10

# %% [markdown]
# <div style="font-family: Segoe UI; line-height: 2; color: #000000; text-align: justify">
#
#    Il y a 10 combinaisons possibles.
# </div>

# %%
# La fonction de la loi binomiale :

def binomial_formula(n, k, p):
    return comb(n, k) * (p**k) * ((1-p)**(n-k))

# %% [markdown]
# $$ C(n, k) \cdot p^k \cdot (1-p)^{n-k} $$

# %% [markdown]
# <a id='question1'></a>
# # <div style=" background-color:#252549; color:white; padding: 12px; line-height: 1.5;">2. | Question n°01</div>

# %% [markdown]
# <div style="font-family: Segoe UI; font-size: 16px; line-height: 2; color: #000000; text-align: justify">
# Quelle est la probabilité qu'exactement <span style="background-color: #D3D3E9; color: #000000;"><b>250 demandes de remboursement</b></span> parmi <span style="background-color: #D3D3E9; color: #000000;"><b>les 1000 reçues ce mois-ci soient acceptées en raison d'un accident ?</b></span>
#     </div>

# %%
round(binomial_formula(1_000, 250, 0.25),4)*100
# Out:
# 2.91

# %% [markdown]
# <div style="font-family: Segoe UI; line-height: 2; color: #000000; text-align: justify">
#
#    La probabilité qu’exactement 250 prêts se soldent par un défaut est de <span style="background-color: #D3D3E9; color: #000000;"><b>2.91%.</b></span>
# </div>

# %%
# 250 de demandes de remboursement, chaque demande acceptée est égale à une perte de 3 000€

250 * 3_000
# Out:
# 750000

# %% [markdown]
# <div style="font-family: Segoe UI; line-height: 2; color: #000000; text-align: justify">
#
#    Ce qui correspond à une perte de <span style="background-color: #D3D3E9; color: #000000;"><b>750 000€.</b></span>
# </div>

# %% [markdown]
# <a id='question2'></a>
# # <div style=" background-color:#252549; color:white; padding: 12px; line-height: 1.5;">3. | Question n°02</div>

# %% [markdown]
# <div style="font-family: Segoe UI; font-size: 16px; line-height: 2; color: #000000; text-align: justify">
# Quelle est la probabilité qu'au moins <span style="background-color: #D3D3E9; color: #000000;"><b>250 demandes de remboursement</b></span> parmi <span style="background-color: #D3D3E9; color: #000000;"><b>les 1000 reçues ce mois-ci soient acceptées en raison d'un accident ?</b></span>
#     </div>

# %%
# Créer une liste qui va contenir toutes les probabilités supérieures ou égales à 250
plus_grand_que_250 = []

# Avec une boucle for, calculer chaque probabilité supérieur à 250
for i in range(250, 1_001):
    # Enregistrer chaque probabilité dans la liste
    plus_grand_que_250.append(binomial_formula(1_000, i, 0.25))

# Faire la somme de la liste

round(sum(plus_grand_que_250), 4) *100
# Out:
# 51.21

# %% [markdown]
# <div style="font-family: Segoe UI; line-height: 2; color: #000000; text-align: justify">
#    La probabilité qu’au moins 250 demandes de remboursement parmi les 1 000 reçues soient acceptées en raison d’un accident est de <span style="background-color: #D3D3E9; color: #000000;"><b>51%.</b></span>
# </div>

# %%
# 1 000 demandes de remboursement, chaque demande acceptée est égale à une perte de 3 000€

1_000 * 3_000
# Out:
# 3000000

# %% [markdown]
# <div style="font-family: Segoe UI; line-height: 2; color: #000000; text-align: justify">
#    La probabilité de rembourser entre <span style="background-color: #D3D3E9; color: #000000;"><b>750 000 et 3 000 000</b></span> est de <span style="background-color: #D3D3E9; color: #000000;"><b>51%.</b></span>
# </div>

# %% [markdown]
# <a id='question3'></a>
# # <div style=" background-color:#252549; color:white; padding: 12px; line-height: 1.5;">4. | Question n°03</div>

# %% [markdown]
# <div style="font-family: Segoe UI; font-size: 16px; line-height: 2; color: #000000; text-align: justify">
# La compagnie ne peut pas dépasser le montant de <span style="background-color: #D3D3E9; color: #000000;"><b>600 000 €</b></span> pour couvrir les remboursements.
#     <br>
# Quelle est <span style="background-color: #D3D3E9; color: #000000;"><b>la probabilité de ne pas dépasser le montant de 600 000€ ?</b></span>
#     </div>

# %%
# Le nombre de demande qui est égale à 600 000€ dde perte est de :

600_000/3_000
# Out:
# 200.0

# %% [markdown]
# <div style="font-family: Segoe UI; line-height: 2; color: #000000; text-align: justify">
#
#    Au bout de <span style="background-color: #D3D3E9; color: #000000;"><b>200 demandes acceptées,</b></span> la perte sera égale à 600 000 €.
# </div>

# %%
# Créer une liste qui va contenir toutes les probabilités inférieures ou égales à 200
plus_petit_que_200 = []

# Avec une boucle for, calculer toutes les probabilités supérieures à 34
for i in range(0,201):
    # Enregistrer chaque probabilité dans la liste
    plus_petit_que_200.append(binomial_formula(1_000, i, 0.25))
    
# Faire la somme de la liste
round(sum(plus_petit_que_200), 6)*100
# Out:
# 0.0109

# %% [markdown]
# <div style="font-family: Segoe UI; line-height: 2; color: #000000; text-align: justify">
#    La probabilité de ne pas dépasser 600 000€ de remboursement est <span style="background-color: #D3D3E9; color: #000000;"><b>de 0.01%.</b></span>
#     <br>
#    Cela signifie que la probabilité <span style="background-color: #D3D3E9; color: #000000;"><b>de dépasser 600 000€</b></span> de remboursement est de <span style="background-color: #D3D3E9; color: #000000;"><b>99,99%.</b></span>
# </div>

# %% [markdown]
# <a id='question4'></a>
# # <div style=" background-color:#252549; color:white; padding: 12px; line-height: 1.5;">5. | Question n°04</div>

# %% [markdown]
# <div style="font-family: Segoe UI; font-size: 16px; line-height: 2; color: #000000; text-align: justify">
# Quelle est la probabilité que <span style="background-color: #D3D3E9; color: #000000;"><b>l’assurance paie entre 600 000 € et 900 000 €</b></span> pour couvrir les remboursements ?
#     </div>

# %% [markdown]
# <div style="font-family: Segoe UI; line-height: 2; color: #000000; text-align: justify">
#
#    Au bout de <span style="background-color: #D3D3E9; color: #000000;"><b>200 demandes acceptées,</b></span> la perte sera égale à 600 000 €.
# </div>

# %%
# Le nombre de demandes qui est égale à 900 000€ de perte est de :
900_000 / 3_000
# Out:
# 300.0

# %% [markdown]
# <div style="font-family: Segoe UI; line-height: 2; color: #000000; text-align: justify">
#
#    Au bout de <span style="background-color: #D3D3E9; color: #000000;"><b>300 demandes acceptées,</b></span> la perte sera égale à 900 000 €.
# </div>

# %%
# Créer une liste qui va contenir toutes les probabilités entre 200 et 300
entre_200_300 = []

# Avec une boucle for, calculer toutes les probabilités supérieures à 200 jusqu'à 300
for i in range(200, 301):
    entre_200_300.append(binomial_formula(1_000, i, 0.25))
    
# Faire la somme de la liste
round(sum(entre_200_300), 4) *100
# Out:
# 99.98

# %% [markdown]
# <div style="font-family: Segoe UI; line-height: 2; color: #000000; text-align: justify">
#    La probabilité que l’assurance paie entre <span style="background-color: #D3D3E9; color: #000000;"><b>600 000€ et 900 000€</b></span> est de <span style="background-color: #D3D3E9; color: #000000;"><b>99,9%.</b></span>
# </div>

# %% [markdown]
# <a id='question5'></a>
# # <div style=" background-color:#252549; color:white; padding: 12px; line-height: 1.5;">6. | Question n°05</div>

# %% [markdown]
# <div style="font-family: Segoe UI; font-size: 16px; line-height: 2; color: #000000; text-align: justify">
# En utilisant une simulation Monte Carlo avec <span style="background-color: #D3D3E9; color: #000000;"><b>10 000 itérations</b></span>, <span style="background-color: #D3D3E9; color: #000000;"><b>calculez la distribution des coûts totaux des remboursements</b></span> et déterminez <span style="background-color: #D3D3E9; color: #000000;"><b>la probabilité que les coûts dépassent 750 000 € ce mois-ci.</b></span>
#     <br><br>
# La simulation Monte Carlo permet d’estimer <span style="background-color: #D3D3E9; color: #000000;"><b>de manière empirique un événement.</b></span>
#     </div>

# %% [markdown]
# ## <div style=" background-color:#4A4A90; color:white; padding: 12px; line-height: 1.5;">Approche classique</div>

# %%
# Le nombre de demandes qui est égale à 750 000€ de perte est de :
750_000/3_000
# Out:
# 250.0

# %% [markdown]
# <div style="font-family: Segoe UI; line-height: 2; color: #000000; text-align: justify">
#
#    Au bout de <span style="background-color: #D3D3E9; color: #000000;"><b>250 demandes acceptées,</b></span> la perte sera égale à 750 000 €.
# </div>

# %%
# Créer une liste qui va contenir toutes les probabilités supérieures ou égales à 250
plus_grand_que_250 = []

# Avec une boucle for, calculer chaque probabilité supérieur à 250
for i in range(250, 1_001):
    # Enregistrer chaque probabilité dans la liste
    plus_grand_que_250.append(binomial_formula(1_000, i, 0.25))

# Faire la somme de la liste

round(sum(plus_grand_que_250), 4) *100
# Out:
# 51.21

# %% [markdown]
# <div style="font-family: Segoe UI; line-height: 2; color: #000000; text-align: justify">
#    La probabilité que l’assurance paie plus de <span style="background-color: #D3D3E9; color: #000000;"><b>750 000€</b></span> est de <span style="background-color: #D3D3E9; color: #000000;"><b>51,2%.</b></span>
# </div>

# %% [markdown]
# ## <div style=" background-color:#4A4A90; color:white; padding: 12px; line-height: 1.5;">Approche avec la simulation de Monte Carlo</div>

# %% [markdown]
# <div style="font-family: Segoe UI; line-height: 2; color: #000000; text-align: justify">
# La simulation de Monte Carlo permet <span style="background-color: #D3D3E9; color: #000000;"><b>d’estimer de manière empirique un événement.</b></span>
#
# <u>Comment allons-nous procéder ?</u>
#
# Nous allons <span style="background-color: #D3D3E9; color: #000000;"><b>générer de manière aléatoire un nombre de réclamations acceptées</b></span> en utilisant la distribution binomiale avec une probabilité de 0.25.
#
#
# <b><u>Par exemple :</u></b> Nous générons 233 réclamations qui sont acceptées.
#
# Nous calculons le coût total des réclamations acceptées <span style="background-color: #D3D3E9; color: #000000;"><b>en multipliant</b></span> le nombre de réclamations acceptées par le montant moyen de remboursement, <span style="background-color: #D3D3E9; color: #000000;"><b>soit : 233 * 3 000 = 699 000.</b></span>
#
# Avec 233 réclamations acceptées, l’assurance paie 699 000€.
# Nous avons réalisé 1 itération, <span style="background-color: #D3D3E9; color: #000000;"><b>nous allons produire cette simulation 10 000 fois</b></span>, et <span style="background-color: #D3D3E9; color: #000000;"><b>regarder combien de fois nous dépassons 750 000€.</b></span>
# Si sur 10 000 itérations, <span style="background-color: #D3D3E9; color: #000000;"><b>5 000 sont supérieurs à 750 000€</b></span>, alors la probabilité de dépasser 750 000€ est de <span style="background-color: #D3D3E9; color: #000000;"><b>50%.</b></span>
#
# <u>Comment allons-nous générer de manière aléatoire un nombre de réclamations acceptées ?</u>
#
# Allons-nous choisir un nombre aléatoire entre 0 et 10 000 ?
# Presque, le problème de choisir un nombre entre 0 et 10 000 est que la distribution est uniforme. Nous, <span style="background-color: #D3D3E9; color: #000000;"><b>nous avons une distribution binomiale</b></span>. Il y a une plus grande probabilité que l’assurance <span style="background-color: #D3D3E9; color: #000000;"><b>accorde le remboursement de 200 réclamations que de 0.</b></span> Il faut que le hasard suive la distribution binomiale.
# </div>

# %%
# Créer la distribution binomiale
vraie_distribution = []
for i in range(1001):
    vraie_distribution.append(binomial_formula(1000, i, 0.25))

# %%
# Importer les bibliothèques
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from highlight_text import HighlightText, ax_text, fig_text

# %%
# Visualiser la distribution des demandes de remboursement

# Taille et qualité du graphique
fig = plt.figure(figsize=(10,7), dpi = 600)
gs = fig.add_gridspec(6, 3)
ax = fig.add_subplot(gs[:3, :])

# Distribution des demandes de remboursement
plt.stackplot(range(1001), vraie_distribution, alpha=0.5, color = "#4A4A90")
sns.lineplot(vraie_distribution, color='#4A4A90')

# Enlever le cadre en haut et à droite
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

# Ajouter des grilles
plt.grid(axis='x', which='major', alpha=0.75, linestyle='dotted', zorder=1)
plt.grid(axis='y', alpha=0, zorder=2)


# Ajouter un cadre en bas et à gauche
ax.spines['bottom'].set_linewidth(1.2)
ax.spines['bottom'].set_color('#CAC9CD')

ax.spines['left'].set_linewidth(1.2)
ax.spines['left'].set_color('#CAC9CD')


# Changer la couleur des barres des graduations sur l'axe x
ax.tick_params(axis='x', colors='#CAC9CD', width=1.2)
ax.tick_params(axis='y', colors='#CAC9CD', width=1.2)

plt.xticks(range(150, 351, 50), fontsize=6, color='#202020', ha='center', rotation=0)
plt.yticks(fontsize=6, color='#202020')
plt.tick_params(left='on', bottom='on')

#Légende
plt.xlim(175,325)

# Customiser les titres

# Couleur
highlight_textprops = [{"fontsize":14, "color":'#262626', "fontname": "Lisboa Sans OSF", "fontweight": "heavy"},
                       {"fontsize":11, "color":'#202020', "fontname": "Cover sans"},
                       {"fontsize":11, "color":'#202020', "fontname": "Cover sans", "fontweight": "heavy"},
                       {"fontsize":11, "color":'#202020', "fontname": "Cover sans"},
                       {"fontsize":11, "color":'#4A4A90', "fontname": "Cover sans", "fontweight": "heavy"}]

# Titre
fig_text(x=0.125, y=0.9, va='bottom',
         s="<Distribution binomiale des réclamations d'assurance>\n"
         "<La ><distribution binomiale ><suit une ><distribution normale.>",
         highlight_textprops=highlight_textprops,
         ax=ax)

# Couleur
highlight_textprops1 = [{"fontsize":10, "color":'#262626', "fontname": "Lisboa Sans OSF", "fontweight": "heavy"}]

# Définir le nom de l'axe des x
ax.set_xlabel("Nombre de demandes de remboursement acceptée", **highlight_textprops1[-1])
ax.set_ylabel("Probabilité", **highlight_textprops1[-1])

# Espacer les titres des axes x et y
ax.xaxis.labelpad = 8
ax.yaxis.labelpad = 8 

# Footnotes
notes_textprops = [{"fontsize":7, "color":'#202020', "style" : "italic", "fontname": "Cover sans"}]
fig_text(x=0.77, y=0.35,
              va='top',
              s='<*https://youtube.com/@FeelDidaxie>',
              highlight_textprops=notes_textprops,
              ax=ax)

plt.show()

# %% [markdown]
# <div style="font-family: Segoe UI; line-height: 2; color: #000000; text-align: justify">
#    La distribution binomiale suit une <span style="background-color: #D3D3E9; color: #000000;"><b>distribution normale.</b></span> Nous remarquons que la probabilité d'avoir entre <span style="background-color: #D3D3E9; color: #000000;"><b>240 et 260 réclamations acceptées </b></span> est <span style="background-color: #D3D3E9; color: #000000;"><b> supérieure </b></span> à celle d'avoir entre <span style="background-color: #D3D3E9; color: #000000;"><b> 180 et 200.</b></span>
#     <br>
#     Donc le nombre que nous devons générer aléatoirement doit <span style="background-color: #D3D3E9; color: #000000;"><b> suivre cette distribution.</b></span>
# </div>

# %%
# Renvoie un nombre aléatoire en suivant cette distribution binomiale avec 1 000 tirages
# et 25% de chances que l'événement se produise
np.random.seed(42)

nbr_reclamation_acceptee = np.random.binomial(1_000, 0.25)
cout = nbr_reclamation_acceptee * 3_000
cout
# Out:
# 720000

# %%
# Créer une variable qui va mesurer le nombre de réclamations supérieures à 750 000e

plus_grand_que_750_000 = 0

if cout >= 750_000:
    plus_grand_que_750_000 +=1

plus_grand_que_750_000
# Out:
# 0

# %%
np.random.seed(42)

# Initialise la variable par 0
plus_grand_que_750_000 = 0

# Créer une boucle for allant jusqu'à 10 000
for i in range(10_000):
    # Génère un nombre aléatoire de la distribution binomiale avec 1 000 tirages et une probabilité de 25%
    nbr_reclamation_acceptee = np.random.binomial(1_000, 0.25)
    # Mesure le coût en fonction du nombre de réclamations acceptées
    cout = nbr_reclamation_acceptee * 3_000
    # Si le coût est supérieur à 750 000, nous ajoutons un "1"
    if cout >= 750_000:
        plus_grand_que_750_000 +=1
        
print(f"La probabilité est : {round((plus_grand_que_750_000/10_000)*100, 4)}%")
# Out:
# La probabilité est : 50.96%

# %% [markdown]
# <div style="font-family: Segoe UI; line-height: 2; color: #000000; text-align: justify">
#    La probabilité que les coûts dépassent 750 000€ est de <span style="background-color: #D3D3E9; color: #000000;"><b>50,96%.</b></span> C’est-à-dire que sur 10 000 simulations, <span style="background-color: #D3D3E9; color: #000000;"><b>5 096 fois</b></span> les coûts dépassent 750 000€.
#     <br>
#     Cette probabilité est pratiquement <span style="background-color: #D3D3E9; color: #000000;"><b>la même </b></span> qu’avec l’approche classique à quelques centièmes près.
# </div>

# %%
#Générer 10 000 nombre aléatoire
np.random.seed(42)

distribution_monte_carlo = np.random.binomial(1000, 0.25, size = 10_000)

# %%
# Visualiser la distribution des demandes de remboursement

# Taille et qualité du graphique
fig = plt.figure(figsize=(10,7), dpi = 600)
gs = fig.add_gridspec(6, 3)
ax = fig.add_subplot(gs[:3, :])

# Distribution des demandes de remboursement
plt.hist(distribution_monte_carlo, bins = range(0, 1001), density = True, alpha = 0.6, label = "Empirique", color = "#4A4A90")

# Enlever le cadre en haut et à droite
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

# Ajouter des grilles
plt.grid(axis='x', which='major', alpha=0.75, linestyle='dotted', zorder=1)
plt.grid(axis='y', alpha=0, zorder=2)


# Ajouter un cadre en bas et à gauche
ax.spines['bottom'].set_linewidth(1.2)
ax.spines['bottom'].set_color('#CAC9CD')

ax.spines['left'].set_linewidth(1.2)
ax.spines['left'].set_color('#CAC9CD')


# Changer la couleur des barres des graduations sur l'axe x
ax.tick_params(axis='x', colors='#CAC9CD', width=1.2)
ax.tick_params(axis='y', colors='#CAC9CD', width=1.2)

plt.xticks(range(150, 351, 50), fontsize=6, color='#202020', ha='center', rotation=0)
plt.yticks(fontsize=6, color='#202020')
plt.tick_params(left='on', bottom='on')

#Légende
plt.xlim(200,300)

# Customiser les titres

# Couleur
highlight_textprops = [{"fontsize":14, "color":'#262626', "fontname": "Lisboa Sans OSF", "fontweight": "heavy"},
                       {"fontsize":11, "color":'#4A4A90', "fontname": "Cover sans", "fontweight": "heavy"},
                       {"fontsize":11, "color":'#202020', "fontname": "Cover sans"}]

# Titre
fig_text(x=0.125, y=0.9, va='bottom',
         s="<Distribution binomiale simulée par la méthode de Monte Carlo>\n"
         "<Approche empirique ><avec la méthode de Monte Carlo. >",
         highlight_textprops=highlight_textprops,
         ax=ax)

# Couleur
highlight_textprops1 = [{"fontsize":10, "color":'#262626', "fontname": "Lisboa Sans OSF", "fontweight": "heavy"}]

# Définir le nom de l'axe des x
ax.set_xlabel("Nombre de demandes de remboursement acceptée", **highlight_textprops1[-1])
ax.set_ylabel("Probabilité", **highlight_textprops1[-1])

# Espacer les titres des axes x et y
ax.xaxis.labelpad = 8
ax.yaxis.labelpad = 8 

# Footnotes
notes_textprops = [{"fontsize":7, "color":'#202020', "style" : "italic", "fontname": "Cover sans"}]
fig_text(x=0.77, y=0.35,
              va='top',
              s='<*https://youtube.com/@FeelDidaxie>',
              highlight_textprops=notes_textprops,
              ax=ax)

# Légende
font_properties = {'family': 'Cover sans', 'weight': 'normal', 'size': 10}
plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.2), fancybox=False, shadow=False, ncol=2, frameon=False, prop=font_properties)

plt.show()

# %%
# Visualiser la distribution des demandes de remboursement

# Taille et qualité du graphique
fig = plt.figure(figsize=(10,7), dpi = 600)
gs = fig.add_gridspec(6, 3)
ax = fig.add_subplot(gs[:3, :])

# Distribution des demandes de remboursement
plt.hist(distribution_monte_carlo, bins = range(0, 1001), density = True, alpha = 0.4, label = "Empirique", color = "#4A4A90")
sns.lineplot(vraie_distribution, color='#252549', label = "Théorique", linewidth = 2.5)

# Enlever le cadre en haut et à droite
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

# Ajouter des grilles
plt.grid(axis='x', which='major', alpha=0.75, linestyle='dotted', zorder=1)
plt.grid(axis='y', alpha=0, zorder=2)


# Ajouter un cadre en bas et à gauche
ax.spines['bottom'].set_linewidth(1.2)
ax.spines['bottom'].set_color('#CAC9CD')

ax.spines['left'].set_linewidth(1.2)
ax.spines['left'].set_color('#CAC9CD')


# Changer la couleur des barres des graduations sur l'axe x
ax.tick_params(axis='x', colors='#CAC9CD', width=1.2)
ax.tick_params(axis='y', colors='#CAC9CD', width=1.2)

plt.xticks(range(150, 351, 50), fontsize=6, color='#202020', ha='center', rotation=0)
plt.yticks(fontsize=6, color='#202020')
plt.tick_params(left='on', bottom='on')

#Légende
plt.xlim(200,300)

# Customiser les titres

# Couleur
highlight_textprops = [{"fontsize":14, "color":'#262626', "fontname": "Lisboa Sans OSF", "fontweight": "heavy"},
                       {"fontsize":11, "color":'#202020', "fontname": "Cover sans"},
                       {"fontsize":11, "color":'#202020', "fontname": "Cover sans", "fontweight": "heavy"},
                       {"fontsize":11, "color":'#202020', "fontname": "Cover sans"},
                       {"fontsize":11, "color":'#4A4A90', "fontname": "Cover sans", "fontweight": "heavy"}]

# Titre
fig_text(x=0.125, y=0.9, va='bottom',
         s="<Distribution binomiale empirique et théorique>\n"
         "<La ><distribution empirique ><suit la ><distribution théorique.>",
         highlight_textprops=highlight_textprops,
         ax=ax)

# Couleur
highlight_textprops1 = [{"fontsize":10, "color":'#262626', "fontname": "Lisboa Sans OSF", "fontweight": "heavy"}]

# Définir le nom de l'axe des x
ax.set_xlabel("Nombre de demandes de remboursement acceptée", **highlight_textprops1[-1])
ax.set_ylabel("Probabilité", **highlight_textprops1[-1])

# Espacer les titres des axes x et y
ax.xaxis.labelpad = 8
ax.yaxis.labelpad = 8 

# Footnotes
notes_textprops = [{"fontsize":7, "color":'#202020', "style" : "italic", "fontname": "Cover sans"}]
fig_text(x=0.77, y=0.35,
              va='top',
              s='<*https://youtube.com/@FeelDidaxie>',
              highlight_textprops=notes_textprops,
              ax=ax)

# Légende
font_properties = {'family': 'Cover sans', 'weight': 'normal', 'size': 10}
plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.2), fancybox=False, shadow=False, ncol=2, frameon=False, prop=font_properties)

plt.show()

# %% [markdown]
# <div style="font-family: Segoe UI; font-size: 16px; line-height: 2; color: #000000; text-align: justify">
# <b><u>Pourquoi utiliser la simulation de Monte Carlo, alors que l’approche classique donne les mêmes résultats ?</u></b>
#     </div>

# %% [markdown]
# <div style="font-family: Segoe UI; line-height: 2; color: #000000; text-align: justify">
#    Dans certains cas, il est difficile de <span style="background-color: #D3D3E9; color: #000000;"><b>calculer analytiquement les probabilités.</b></span> Par exemple, si nous voulons calculer la probabilité de succès d’un événement improbable, <span style="background-color: #D3D3E9; color: #000000;"><b> il devient complexe de résoudre ce problème de manière analytique.</b></span> Mais avec la simulation de Monte Carlo, nous pouvons <span style="background-color: #D3D3E9; color: #000000;"><b> modéliser des scénarios complexes de manière simple et estimer la probabilité d’un événement quasi improbable.</b></span>
#     <br>
# </div>
