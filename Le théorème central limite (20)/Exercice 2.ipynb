# %% [markdown]
# <center> <h1 style="background-color:#264655; padding: 4px; color:white" >Commerce électronique</h1>
#
# <br>
#
# <center><img
# src="https://miro.medium.com/v2/resize:fit:670/0*EVTnmRoDHotaLydW"
#              style="width:50%;height:50%;">
# </center>
#
#
# <div class="list-group" id="list-tab" role="tablist">
#
#   <h3 class="list-group-item list-group-item-action active" style="background-color:#264655; color:white" data-toggle="list"  role="tab" aria-controls="home">Sommaire</h3>
#   <a class="list-group-item list-group-item-action" data-toggle="list" href="#introduction" role="tab" aria-controls="profile" style="color:#264655">Introduction<span class="badge badge-primary badge-pill" style="background-color:#264655; color:white">1</span></a>
#   <a id="section2" class="list-group-item list-group-item-action" data-toggle="list" href="#question1" role="tab" aria-controls="messages" style="color:#264655">Question n°01<span class="badge badge-primary badge-pill" style="background-color:#264655; color:white">2</span></a>
#   <a id="section2" class="list-group-item list-group-item-action" data-toggle="list" href="#question2" role="tab" aria-controls="messages" style="color:#264655">Question n°02<span class="badge badge-primary badge-pill" style="background-color:#264655; color:white">3</span></a>
#   <a id="section2" class="list-group-item list-group-item-action" data-toggle="list" href="#question3" role="tab" aria-controls="messages" style="color:#264655">Question n°03<span class="badge badge-primary badge-pill" style="background-color:#264655; color:white">4</span></a>
#   <a id="section2" class="list-group-item list-group-item-action" data-toggle="list" href="#question4" role="tab" aria-controls="messages" style="color:#264655">Question n°04<span class="badge badge-primary badge-pill" style="background-color:#264655; color:white">5</span></a>
#   <a id="section2" class="list-group-item list-group-item-action" data-toggle="list" href="#question5" role="tab" aria-controls="messages" style="color:#264655">Question n°05<span class="badge badge-primary badge-pill" style="background-color:#264655; color:white">6</span></a>
#   <a id="section2" class="list-group-item list-group-item-action" data-toggle="list" href="#question6" role="tab" aria-controls="messages" style="color:#264655">Question n°06<span class="badge badge-primary badge-pill" style="background-color:#264655; color:white">7</span></a>
#   <a id="section2" class="list-group-item list-group-item-action" data-toggle="list" href="#question7" role="tab" aria-controls="messages" style="color:#264655">Question n°07<span class="badge badge-primary badge-pill" style="background-color:#264655; color:white">8</span></a>
#   <a id="section2" class="list-group-item list-group-item-action" data-toggle="list" href="#question8" role="tab" aria-controls="messages" style="color:#264655">Question n°08<span class="badge badge-primary badge-pill" style="background-color:#264655; color:white">9</span></a>
#   <a id="section2" class="list-group-item list-group-item-action" data-toggle="list" href="#question9" role="tab" aria-controls="messages" style="color:#264655">Question n°09<span class="badge badge-primary badge-pill" style="background-color:#264655; color:white">10</span></a>
#     </div>

# %% [markdown]
# <a id='introduction'></a>
# # <div style=" background-color:#264655; color:white; padding: 12px; line-height: 1.5;">1. | Introduction</div>

# %% [markdown]
# ## <div style=" background-color: #2A9D90; color:white; padding: 10px; line-height: 1.5;"> Énoncé
# </div>
# <div style="font-family: Segoe UI; line-height: 2; color: #000000; text-align: justify">
#
#    👉 Imaginez que vous travaillez pour une entreprise de commerce électronique. Vous avez accès à une grande base de données contenant des informations sur les achats de clients, y compris le montant de chaque achat.
# </div>

# %% [markdown]
# ## <div style=" background-color: #2A9D90; color:white; padding: 10px; line-height: 1.5;"> Importer les bibliothèques 📚
# </div>

# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# <a id='question1'></a>
# # <div style=" background-color:#264655; color:white; padding: 12px; line-height: 1.5;">2. | Question n°01</div>

# %% [markdown]
# <div style="font-family: Segoe UI; font-size: 16px; line-height: 2; color: #000000; text-align: justify">
#
# <span style="background-color: #D4F4F0; color: #000000;"><b>Générez 10 000 montants aléatoires entre 10 et 1 000€.</b></span>
#
# </div>

# %%
np.random.seed(100)

montants = np.random.uniform(10, 1_000, 10_000).round(2)

# %% [markdown]
# <a id='question2'></a>
# # <div style=" background-color:#264655; color:white; padding: 12px; line-height: 1.5;">3. | Question n°02</div>

# %% [markdown]
# <div style="font-family: Segoe UI; font-size: 16px; line-height: 2; color: #000000; text-align: justify">
#
# Visualisez <span style="background-color: #D4F4F0; color: #000000;"><b>la distribution des notes</b></span> des montants.
# </div>

# %%
plt.figure(figsize=(12,5), dpi = 200)

plt.hist(montants, bins = 50, density = True, alpha = 0.7, label = "Population")

plt.title("Distribution des montants dans la population")
plt.xlabel("Montants")
plt.ylabel("Fréquence")
plt.show()

# %% [markdown]
# <div style="font-family: Segoe UI; line-height: 2; color: #000000; text-align: justify">
#
# Nous observons que <span style="background-color: #D4F4F0; color: #000000;"><b>la distribution suit une distribution uniforme,</b></span> ce qui est logique car les nombres sont générées à partir d’une distribution uniforme.
# </div>

# %% [markdown]
# <a id='question3'></a>
# # <div style=" background-color:#264655; color:white; padding: 12px; line-height: 1.5;">4. | Question n°03</div>

# %% [markdown]
# <div style="font-family: Segoe UI; font-size: 16px; line-height: 2; color: #000000; text-align: justify">
#
# <span style="background-color: #D4F4F0; color: #000000;"><b> Calculez la moyenne et l'écart type des montants de la classe.</b></span>
# </div>

# %%
moyenne = np.mean(montants).round(1)

print(f"La moyenne est égale à : {moyenne}")
# Out:
# La moyenne est égale à : 502.7

# %%
ecart_type = np.std(montants).round(2)

print(f"L'écart type est égale à : {ecart_type}")
# Out:
# L'écart type est égale à : 286.17

# %% [markdown]
# <a id='question4'></a>
# # <div style=" background-color:#264655; color:white; padding: 12px; line-height: 1.5;">5. | Question n°04</div>

# %% [markdown]
# <div style="font-family: Segoe UI; font-size: 16px; line-height: 2; color: #000000; text-align: justify">
#
# <span style="background-color: #D4F4F0; color: #000000;"><b>Prenez un échantillon aléatoire de 50 transactions parmi les 10 000.</b></span>
# </div>

# %%
np.random.seed(100)

echantillon = np.random.choice(montants, size = 50)

# %%
plt.figure(figsize=(12,5), dpi = 200)

plt.hist(echantillon, bins = 30, density = True, alpha = 0.7, label = "Échantillon")

plt.title("Distribution des montants de l'échantillon")
plt.xlabel("Montants")
plt.ylabel("Fréquence")
plt.show()

# %% [markdown]
# <div style="font-family: Segoe UI; line-height: 2; color: #000000; text-align: justify">
#
# Nous observons que la distribution <span style="background-color: #D4F4F0; color: #000000;"><b>ne suit pas la distribution normale.</b></span>
# </div>

# %% [markdown]
# <a id='question5'></a>
# # <div style=" background-color:#264655; color:white; padding: 12px; line-height: 1.5;">6. | Question n°05</div>

# %% [markdown]
# <div style="font-family: Segoe UI; font-size: 16px; line-height: 2; color: #000000; text-align: justify">
#
# <span style="background-color: #D4F4F0; color: #000000;"><b>Effectuez une simulation où vous générez 1 000 moyennes d'échantillons aléatoires différentes de 50 transactions et 1 000 écarts types d'échantillons différents.</b></span>
# </div>

# %%
np.random.seed(100)

moyenne_echantillons = []

for i in range(1_000):
    moyenne_echantillons.append(np.mean(np.random.choice(montants, size = 50)).round(2))

# %%
moyenne_echantillons
# Out:
# [479.99,
#  552.92,
#  489.26,
#  471.84,
#  525.99,
#  459.53,
#  543.57,
#  508.22,
#  532.29,
#  521.88,
#  443.61,
#  493.38,
#  508.25,
#  466.96,
#  522.79,
#  571.09,
#  426.61,
#  491.7,
#  502.89,
#  517.74,
#  489.03,
#  458.05,
#  495.84,
#  487.79,
#  453.86,
#  520.01,
#  571.93,
#  528.45,
#  495.7,
#  494.53,
#  482.03,
#  532.23,
#  544.59,
#  489.86,
#  535.89,
#  453.26,
#  430.14,
#  576.53,
#  515.49,
#  542.89,
#  624.39,
#  520.9,
#  525.43,
#  488.0,
#  428.54,
#  478.35,
#  514.61,
#  532.88,
#  459.67,
#  507.81,
#  505.52,
#  516.81,
#  481.51,
#  494.7,
#  457.7,
#  526.08,
#  499.18,
#  507.78,
#  544.86,
#  480.57,
#  501.96,
#  528.51,
#  551.81,
#  514.24,
#  447.89,
#  484.71,
#  552.23,
#  485.65,
#  527.53,
#  572.08,
#  472.32,
#  501.31,
#  446.33,
#  566.09,
#  524.35,
#  521.43,
#  486.69,
#  448.37,
#  503.08,
#  459.75,
#  444.1,
#  503.54,
#  429.73,
#  506.04,
#  598.87,
#  501.49,
#  467.28,
#  448.88,
#  474.89,
#  515.03,
#  514.73,
# ...

# %%
np.random.seed(100)

ecart_type_echantillons = []

for i in range(1_000):
    ecart_type_echantillons.append(np.std(np.random.choice(montants, size = 50)).round(2))

# %%
ecart_type_echantillons
# Out:
# [251.88,
#  273.34,
#  303.33,
#  261.77,
#  265.5,
#  288.39,
#  303.83,
#  306.72,
#  288.39,
#  271.05,
#  274.02,
#  299.66,
#  292.47,
#  297.34,
#  272.67,
#  308.03,
#  248.29,
#  279.45,
#  290.86,
#  280.19,
#  269.44,
#  285.62,
#  278.98,
#  290.83,
#  279.2,
#  273.36,
#  300.84,
#  270.11,
#  298.63,
#  293.17,
#  295.52,
#  291.24,
#  304.23,
#  310.07,
#  289.41,
#  284.69,
#  296.4,
#  276.83,
#  256.63,
#  294.68,
#  255.83,
#  239.96,
#  269.04,
#  257.44,
#  285.7,
#  261.53,
#  293.47,
#  299.28,
#  262.91,
#  261.95,
#  253.1,
#  275.12,
#  269.18,
#  300.76,
#  299.8,
#  302.32,
#  254.62,
#  265.25,
#  278.25,
#  280.01,
#  295.4,
#  296.84,
#  286.58,
#  295.0,
#  288.48,
#  259.48,
#  298.58,
#  279.58,
#  276.86,
#  279.87,
#  298.48,
#  290.35,
#  269.33,
#  305.12,
#  276.25,
#  299.93,
#  229.94,
#  257.21,
#  295.06,
#  292.8,
#  279.74,
#  296.27,
#  272.74,
#  292.24,
#  262.02,
#  280.14,
#  272.26,
#  230.94,
#  318.46,
#  274.29,
#  292.43,
# ...

# %%
print(f"La moyenne du premier échantillon est : {moyenne_echantillons[0]} et "
     f"l'écart type est : {ecart_type_echantillons[0]}.")
# Out:
# La moyenne du premier échantillon est : 479.99 et l'écart type est : 251.88.

# %% [markdown]
# <a id='question6'></a>
# # <div style=" background-color:#264655; color:white; padding: 12px; line-height: 1.5;">7. | Question n°06</div>

# %% [markdown]
# <div style="font-family: Segoe UI; font-size: 16px; line-height: 2; color: #000000; text-align: justify">
#
# <span style="background-color: #D4F4F0; color: #000000;"><b>
# Calculez la moyenne des moyennes d'échantillons et la moyenne des écart type des échantillons. Comparez-les à la moyenne et à l'écart type de l'ensemble de la classe. </b></span>
# </div>

# %%
moyenne_moyenne_echantillons = np.mean(moyenne_echantillons).round(2)
print(f"La moyenne des moyennes des échantillons est : {moyenne_moyenne_echantillons}")
# Out:
# La moyenne des moyennes des échantillons est : 503.05

# %%
print(f"{moyenne}")
# Out:
# 502.7

# %% [markdown]
# <div style="font-family: Segoe UI; line-height: 2; color: #000000; text-align: justify">
#
# La moyenne des moyennes des échantillons est égale à 503.05. Ce qui est très proche de <span style="background-color: #D4F4F0; color: #000000;"><b>la moyenne réelle qui est égale à 502.7.</b></span>
# </div>

# %%
moyenne_ecart_type_echantillon = np.mean(ecart_type_echantillons).round(1)
print(f"La moyenne des écarts types des échantillons est : {moyenne_ecart_type_echantillon}")
# Out:
# La moyenne des écarts types des échantillons est : 283.5

# %%
print(f"{ecart_type}")
# Out:
# 286.17

# %% [markdown]
# <div style="font-family: Segoe UI; line-height: 2; color: #000000; text-align: justify">
#
# La moyenne des écarts types des échantillons est égale à 283.5. Ce qui est très proche de <span style="background-color: #D4F4F0; color: #000000;"><b>l'écart type réel qui est égal à 286.17.</b></span>
# </div>

# %% [markdown]
# <a id='question7'></a>
# # <div style=" background-color:#264655; color:white; padding: 12px; line-height: 1.5;">8. | Question n°07</div>

# %% [markdown]
# <div style="font-family: Segoe UI; font-size: 16px; line-height: 2; color: #000000; text-align: justify">
#
# <span style="background-color: #D4F4F0; color: #000000;"><b>
# Tracez un histogramme des moyennes d'échantillons. Comparez visuellement cette distribution à une distribution normale.</b></span>
# </div>

# %%
plt.figure(figsize=(12,5), dpi = 200)

plt.hist(moyenne_echantillons, bins = 30, density = True, alpha = 0.7, label = "Échantillon")

plt.title("Distribution des moyennes de 1 000 échantillons")
plt.xlabel("Montants")
plt.ylabel("Fréquence")
plt.show()

# %%
plt.figure(figsize=(12,5), dpi = 200)

plt.hist(montants, bins = 50, density = True, alpha = 0.7, label = "Population")

plt.title("Distribution des montants dans la population")
plt.xlabel("Montants")
plt.ylabel("Fréquence")
plt.show()

# %% [markdown]
# <div style="font-family: Segoe UI; line-height: 2; color: #000000; text-align: justify">
#
# Nous observons que la distribution des moyennes des échantillons suit une <span style="background-color: #D4F4F0; color: #000000;"><b>distribution normale</b></span> même si la population ne suit pas la loi normale.
# </div>

# %% [markdown]
# <a id='question8'></a>
# # <div style=" background-color:#264655; color:white; padding: 12px; line-height: 1.5;">9. | Question n°08</div>

# %% [markdown]
# <div style="font-family: Segoe UI; font-size: 16px; line-height: 2; color: #000000; text-align: justify">
#
# <span style="background-color: #D4F4F0; color: #000000;"><b>
# Calculez l’espérance et l’erreur type de ce processus aléatoire.</b></span>
# </div>

# %% [markdown]
# <div style="font-family: Segoe UI; line-height: 2; color: #000000; text-align: justify">
#
# <span style="background-color: #D4F4F0; color: #000000;"><b>L’espérance de la moyenne obtenue est égale à la moyenne de la boîte.</b></span>
#
#
# La moyenne de la boîte est égale à 502.7. L’espérance prévoit dans un échantillon, <span style="background-color: #D4F4F0; color: #000000;"><b>il devrait y avoir un montant moyen de 502.7€.</b></span>
#
# </div>

# %% [markdown]
# <div style="font-family: Segoe UI; line-height: 2; color: #000000; text-align: justify">
#
#
# <u>L’erreur type pour la somme d’un processus aléatoire est égale à :</u>
#
# $$\sqrt{\text{Nombre de tirages}} \times \text{Écart type}$$
# </div>

# %% [markdown]
# <div style="font-family: Segoe UI; line-height: 2; color: #000000; text-align: justify">
#
# <u>Pour la moyenne d’un échantillon :</u>
#
# $$\frac{\text{Écart type}}{\sqrt{\text{Nombre de tirages}}}$$
# </div>

# %%
erreur_type = ecart_type / np.sqrt(50)
print(f"L'erreur type est égale à : {erreur_type.round(2)}")
# Out:
# L'erreur type est égale à : 40.47

# %% [markdown]
# <div style="font-family: Segoe UI; line-height: 2; color: #000000; text-align: justify">
#
# <span style="background-color: #D4F4F0; color: #000000;"><b>L’espérance prévoit que dans un échantillon, la note moyenne est de 502.7, à plus ou moins 40.7 près.</b></span>
#
# </div>

# %%
print(f"La moyenne des moyennes des échantillons est : {moyenne_moyenne_echantillons}")
# Out:
# La moyenne des moyennes des échantillons est : 503.05

# %%
print(f"L'écart type des moyennes des échantillons est : {np.std(moyenne_echantillons).round(2)}")
# Out:
# L'écart type des moyennes des échantillons est : 39.62

# %% [markdown]
# <a id='question9'></a>
# # <div style=" background-color:#264655; color:white; padding: 12px; line-height: 1.5;">10. | Question n°09</div>

# %% [markdown]
# <div style="font-family: Segoe UI; font-size: 16px; line-height: 2; color: #000000; text-align: justify">
#
# <span style="background-color: #D4F4F0; color: #000000;"><b>
# Calculez la probabilité que la moyenne d'un échantillon de 50 transactions soit supérieure à 600€, en utilisant le z score et en utilisant la distribution des moyennes d’échantillons que vous avez obtenus.</b></span>
# </div>

# %% [markdown]
# ## <div style=" background-color: #2A9D90; color:white; padding: 10px; line-height: 1.5;"> Approche empirique
# </div>

# %%
moyenne_echantillons = np.array(moyenne_echantillons)

# %%
moyenne_sup600 = len(moyenne_echantillons[moyenne_echantillons >= 600])

# %%
len(moyenne_echantillons)
# Out:
# 1000

# %%
(moyenne_sup600 / 1_000)*100
# Out:
# 0.7000000000000001

# %% [markdown]
# <div style="font-family: Segoe UI; line-height: 2; color: #000000; text-align: justify">
#
# <span style="background-color: #D4F4F0; color: #000000;"><b>0.7% des moyennes des échantillons sont supérieurs à 600.</b></span> C'est-à-dire que la probabilité d'obtenir un échantillon avec une moyenne supérieure à 600 est de 0.7%.
#
# </div>

# %% [markdown]
# ## <div style=" background-color: #2A9D90; color:white; padding: 10px; line-height: 1.5;"> Approche théorique
# </div>

# %% [markdown]
# <div style="font-family: Segoe UI; line-height: 2; color: #000000; text-align: justify">
#
# Comme la distribution des moyennes des échantillons suit la loi normale, nous pouvons utiliser le z score.
#
# </div>

# %% [markdown]
# <div style="font-family: Segoe UI; line-height: 2; color: #000000; text-align: justify">
#
# Pour calculer la probabilité que dans un échantillon la moyenne de 50 transactions soit supérieure à 600€, nous calculons le z score.
# </div>

# %% [markdown]
# <div style="font-family: Segoe UI; line-height: 2; color: #000000; text-align: justify">
#
#
# <u>De combien d’erreur type la valeur 600 diffère de l’espérance ?</u>
#
# $$\frac{(X - \text{Espérance})}{\text{Erreur type}}$$
# </div>

# %%
z_score = (600 - moyenne) / erreur_type
print(f"{z_score.round(2)}")
# Out:
# 2.4

# %% [markdown]
# <div style="font-family: Segoe UI; line-height: 2; color: #000000; text-align: justify">
# 600 se situe à <span style="background-color: #D4F4F0; color: #000000;"><b>2.40 erreurs types</b></span> de l’espérance.
# </div>

# %% [markdown]
# <center><img
# src="https://conversion-uplift.co.uk/wp-content/uploads/2016/10/Z-Score-Table-e1662377674110.jpg"
#              style="width:40%;height:40%;">
# </center>

# %% [markdown]
# <div style="font-family: Segoe UI; line-height: 2; color: #000000; text-align: justify">
# <span style="background-color: #D4F4F0; color: #000000;"><b>49,20%</b></span> des échantillons aléatoires sont compris entre 2.40 erreurs types et la moyenne, soit entre 502.7 et 600.
# </div>

# %% [markdown]
# <div style="font-family: Segoe UI; line-height: 2; color: #000000; text-align: justify">
# <span style="background-color: #D4F4F0; color: #000000;"><b>0.8% des échantillons aléatoires sont supérieurs à 600. </b></span>
# </div>

# %% [markdown]
# <div style="font-family: Segoe UI; line-height: 2; color: #000000; text-align: justify">
# La probabilité que dans un échantillon la moyenne soit supérieure à 600 est de 0.8%.
# </div>

# %% [markdown]
# <div style="font-family: Segoe UI; line-height: 2; color: #000000; text-align: justify">
# <span style="background-color: #D4F4F0; color: #000000;"><b>L’approche empirique est extrêmement proche de l’approche théorique,</b></span> et si nous augmentons le nombre d’échantillons, par exemple la distribution des moyennes de 10 000 échantillons, l’approche empirique se rapprochera encore plus de la théorie.
# </div>
