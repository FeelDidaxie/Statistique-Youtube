# %% [markdown]
# <center> <h1 style="background-color:#002F49; padding: 4px; color:white" >Les notes des étudiants</h1>
#
# <br>
#
# <center><img
# src="https://miro.medium.com/v2/resize:fit:700/1*w-ACMUU_VxUgaP5u08HkkA.png"
#              style="width:60%;height:60%;">
# </center>
#
#
# <div class="list-group" id="list-tab" role="tablist">
#
#   <h3 class="list-group-item list-group-item-action active" style="background-color:#002F49; color:white" data-toggle="list"  role="tab" aria-controls="home">Sommaire</h3>
#   <a class="list-group-item list-group-item-action" data-toggle="list" href="#introduction" role="tab" aria-controls="profile" style="color:#002F49">Introduction<span class="badge badge-primary badge-pill" style="background-color:#002F49; color:white">1</span></a>
#   <a id="section2" class="list-group-item list-group-item-action" data-toggle="list" href="#question1" role="tab" aria-controls="messages" style="color:#002F49">Question n°01<span class="badge badge-primary badge-pill" style="background-color:#002F49; color:white">2</span></a>
#   <a id="section2" class="list-group-item list-group-item-action" data-toggle="list" href="#question2" role="tab" aria-controls="messages" style="color:#002F49">Question n°02<span class="badge badge-primary badge-pill" style="background-color:#002F49; color:white">3</span></a>
#   <a id="section2" class="list-group-item list-group-item-action" data-toggle="list" href="#question3" role="tab" aria-controls="messages" style="color:#002F49">Question n°03<span class="badge badge-primary badge-pill" style="background-color:#002F49; color:white">4</span></a>
#   <a id="section2" class="list-group-item list-group-item-action" data-toggle="list" href="#question4" role="tab" aria-controls="messages" style="color:#002F49">Question n°04<span class="badge badge-primary badge-pill" style="background-color:#002F49; color:white">5</span></a>
#   <a id="section2" class="list-group-item list-group-item-action" data-toggle="list" href="#question5" role="tab" aria-controls="messages" style="color:#002F49">Question n°05<span class="badge badge-primary badge-pill" style="background-color:#002F49; color:white">6</span></a>
#   <a id="section2" class="list-group-item list-group-item-action" data-toggle="list" href="#question6" role="tab" aria-controls="messages" style="color:#002F49">Question n°06<span class="badge badge-primary badge-pill" style="background-color:#002F49; color:white">7</span></a>
#   <a id="section2" class="list-group-item list-group-item-action" data-toggle="list" href="#question7" role="tab" aria-controls="messages" style="color:#002F49">Question n°07<span class="badge badge-primary badge-pill" style="background-color:#002F49; color:white">8</span></a>
#   <a id="section2" class="list-group-item list-group-item-action" data-toggle="list" href="#question8" role="tab" aria-controls="messages" style="color:#002F49">Question n°08<span class="badge badge-primary badge-pill" style="background-color:#002F49; color:white">9</span></a>
#   <a id="section2" class="list-group-item list-group-item-action" data-toggle="list" href="#question9" role="tab" aria-controls="messages" style="color:#002F49">Question n°09<span class="badge badge-primary badge-pill" style="background-color:#002F49; color:white">10</span></a>
#   <a id="section2" class="list-group-item list-group-item-action" data-toggle="list" href="#question10" role="tab" aria-controls="messages" style="color:#002F49">Question n°10<span class="badge badge-primary badge-pill" style="background-color:#002F49; color:white">11</span></a>
#     </div>

# %% [markdown]
# <a id='introduction'></a>
# # <div style=" background-color:#002F49; color:white; padding: 12px; line-height: 1.5;">1. | Introduction</div>

# %% [markdown]
# ## <div style=" background-color: #D72729; color:white; padding: 10px; line-height: 1.5;"> Énoncé
# </div>
# <div style="font-family: Segoe UI; line-height: 2; color: #000000; text-align: justify">
#
#    👉 Un enseignant souhaite analyser les notes des étudiants à un examen final dans une promo de 500 étudiants. Il a recueilli les données de notes de tous les étudiants, mais il souhaite <span style="background-color: #F6CECE; color: #000000;"><b>comprendre comment les moyennes de différents échantillons d'étudiants varient par rapport à la moyenne globale.</b></span>
# </div>

# %% [markdown]
# ## <div style=" background-color: #D72729; color:white; padding: 10px; line-height: 1.5;"> Importer les bibliothèques 📚
# </div>

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# <a id='question1'></a>
# # <div style=" background-color:#002F49; color:white; padding: 12px; line-height: 1.5;">2. | Question n°01</div>

# %% [markdown]
# <div style="font-family: Segoe UI; font-size: 16px; line-height: 2; color: #000000; text-align: justify">
#
# Le jeu de données contient <span style="background-color: #F6CECE; color: #000000;"><b>les notes de 500 étudiants</b></span>
# à l’examen final. <span style="background-color: #F6CECE; color: #000000;"><b>Créez une simulation de 500 étudiants avec leurs notes à un examen en Python.</b></span>
# </div>

# %%
np.random.seed(100)

#Génére 500 notes aléatoires entre 0 et 100
notes = np.random.randint(0, 101, 500)

# %% [markdown]
# <a id='question2'></a>
# # <div style=" background-color:#002F49; color:white; padding: 12px; line-height: 1.5;">3. | Question n°02</div>

# %% [markdown]
# <div style="font-family: Segoe UI; font-size: 16px; line-height: 2; color: #000000; text-align: justify">
#
# Visualisez <span style="background-color: #F6CECE; color: #000000;"><b>la distribution des notes</b></span> de la population.
# </div>

# %%
#Taille de l'image
plt.figure(figsize=(12,5), dpi = 200)

plt.hist(notes, bins = 50, density = False, alpha = 0.7, label = "Population")

#Légende
plt.title("Distribution des notes dans la population")
plt.xlabel("Notes")
plt.ylabel("Fréquence")
plt.legend()
plt.show()

# %% [markdown]
# <div style="font-family: Segoe UI; line-height: 2; color: #000000; text-align: justify">
#
# Nous observons que la distribution <span style="background-color: #F6CECE; color: #000000;"><b>ne suit pas la distribution normale,</b></span> elle se rapproche de la distribution uniforme. Ce qui est normal car la fonction « np.random.randint » retourne une distribution uniforme.
# </div>

# %% [markdown]
# <a id='question3'></a>
# # <div style=" background-color:#002F49; color:white; padding: 12px; line-height: 1.5;">4. | Question n°03</div>

# %% [markdown]
# <div style="font-family: Segoe UI; font-size: 16px; line-height: 2; color: #000000; text-align: justify">
#
# <span style="background-color: #F6CECE; color: #000000;"><b> Calculez la moyenne et l'écart type des notes de l'ensemble de la classe.</b></span>
# </div>

# %%
moyenne = np.mean(notes).round(1)

print(f"La moyenne est égale à : {moyenne}")
# Out:
# La moyenne est égale à : 51.0

# %%
ecart_type = np.std(notes).round(1)

print(f"L'écart type est égal à : {ecart_type}")
# Out:
# L'écart type est égal à : 29.3

# %% [markdown]
# <a id='question4'></a>
# # <div style=" background-color:#002F49; color:white; padding: 12px; line-height: 1.5;">5. | Question n°04</div>

# %% [markdown]
# <div style="font-family: Segoe UI; font-size: 16px; line-height: 2; color: #000000; text-align: justify">
#
# <span style="background-color: #F6CECE; color: #000000;"><b>Prenez un échantillon aléatoire de 30 étudiants parmi les 500 et visualisez la distribution.</b></span>
# </div>

# %%
np.random.seed(100)

echantillon = np.random.choice(notes, size = 30)

# %%
plt.figure(figsize=(12,5), dpi = 200)

plt.hist(echantillon, bins = 10, density = False, alpha = 0.7, label = "Population")

plt.title("Distribution des notes de l'échantillon")
plt.xlabel("Notes")
plt.ylabel("Fréquence")
plt.legend()
plt.show()

# %% [markdown]
# <div style="font-family: Segoe UI; line-height: 2; color: #000000; text-align: justify">
#
# Nous observons que la distribution <span style="background-color: #F6CECE; color: #000000;"><b>ne suit pas la distribution normale.</b></span>
# </div>

# %% [markdown]
# <a id='question5'></a>
# # <div style=" background-color:#002F49; color:white; padding: 12px; line-height: 1.5;">6. | Question n°05</div>

# %% [markdown]
# <div style="font-family: Segoe UI; font-size: 16px; line-height: 2; color: #000000; text-align: justify">
#
# <span style="background-color: #F6CECE; color: #000000;"><b>Calculez la moyenne et l’écart type de cet échantillon et enregistrez-la.</b></span>
# </div>

# %%
moyenne_echantillon = np.mean(echantillon).round(1)

print(f"La moyenne est égale à : {moyenne_echantillon}")
# Out:
# La moyenne est égale à : 53.9

# %%
ecart_type_echantillon = np.std(echantillon).round(1)

print(f"L'écart type est égal à : {ecart_type_echantillon}")
# Out:
# L'écart type est égal à : 21.6

# %% [markdown]
# <a id='question6'></a>
# # <div style=" background-color:#002F49; color:white; padding: 12px; line-height: 1.5;">7. | Question n°06</div>

# %% [markdown]
# <div style="font-family: Segoe UI; font-size: 16px; line-height: 2; color: #000000; text-align: justify">
#
# <span style="background-color: #F6CECE; color: #000000;"><b>
# Répétez les étapes 3 et 4, 1 000 fois pour créer 1 000 moyennes d'échantillons différentes et 1 000 écarts types d’échantillons différents.</b></span>
# </div>

# %%
np.random.seed(100)

moyenne_echantillons = []

for i in range(1_000):
    moyenne_echantillons.append(np.mean(np.random.choice(notes, size = 30)).round(1))

# %%
moyenne_echantillons
# Out:
# [53.9,
#  53.3,
#  55.9,
#  49.4,
#  50.4,
#  46.5,
#  55.0,
#  47.8,
#  59.1,
#  44.9,
#  47.1,
#  41.0,
#  64.2,
#  56.0,
#  41.8,
#  52.3,
#  46.3,
#  53.2,
#  50.3,
#  56.6,
#  46.9,
#  55.6,
#  45.2,
#  52.0,
#  43.7,
#  44.0,
#  43.2,
#  55.4,
#  56.5,
#  51.9,
#  46.7,
#  53.5,
#  52.3,
#  51.1,
#  52.2,
#  59.8,
#  52.6,
#  57.2,
#  49.4,
#  44.7,
#  53.1,
#  50.4,
#  50.0,
#  44.5,
#  48.4,
#  51.2,
#  45.1,
#  46.7,
#  50.1,
#  53.8,
#  55.8,
#  46.3,
#  51.0,
#  50.4,
#  49.8,
#  56.7,
#  50.6,
#  44.0,
#  54.2,
#  53.7,
#  56.2,
#  49.2,
#  43.1,
#  58.4,
#  52.0,
#  53.0,
#  55.6,
#  49.1,
#  47.0,
#  52.7,
#  41.8,
#  50.3,
#  48.3,
#  48.8,
#  52.0,
#  59.5,
#  54.9,
#  51.2,
#  51.4,
#  54.2,
#  47.7,
#  55.6,
#  43.8,
#  57.1,
#  49.3,
#  54.0,
#  52.9,
#  58.7,
#  55.3,
#  57.6,
#  46.0,
#  59.2,
#  57.7,
#  52.7,
#  58.8,
#  48.3,
#  49.0,
#  47.7,
#  55.6,
#  48.5,
#  48.2,
#  55.7,
#  46.7,
#  49.3,
#  46.3,
#  49.9,
#  50.7,
#  52.3,
#  51.7,
#  55.3,
#  43.6,
# ...

# %%
np.random.seed(100)

ecart_type_echantillons = []

for i in range(1_000):
    ecart_type_echantillons.append(np.std(np.random.choice(notes, size = 30)).round(1))

# %%
ecart_type_echantillons
# Out:
# [21.6,
#  29.1,
#  31.7,
#  28.3,
#  31.9,
#  32.2,
#  26.5,
#  31.7,
#  31.6,
#  23.9,
#  23.9,
#  25.9,
#  27.0,
#  26.3,
#  33.1,
#  29.4,
#  31.8,
#  28.8,
#  32.5,
#  29.4,
#  27.6,
#  30.3,
#  26.6,
#  26.4,
#  25.9,
#  29.1,
#  24.5,
#  30.2,
#  29.9,
#  30.2,
#  30.0,
#  28.3,
#  33.2,
#  31.3,
#  28.5,
#  33.5,
#  31.4,
#  26.8,
#  30.1,
#  30.6,
#  26.2,
#  27.7,
#  28.6,
#  30.3,
#  25.1,
#  27.7,
#  30.6,
#  27.2,
#  31.9,
#  33.7,
#  30.4,
#  30.9,
#  24.7,
#  30.1,
#  28.9,
#  28.4,
#  26.8,
#  27.8,
#  25.2,
#  29.0,
#  29.6,
#  28.4,
#  33.7,
#  26.4,
#  29.7,
#  31.3,
#  31.1,
#  31.9,
#  32.4,
#  27.1,
#  28.3,
#  27.5,
#  25.0,
#  29.2,
#  28.7,
#  26.8,
#  33.3,
#  30.8,
#  26.6,
#  33.0,
#  21.7,
#  30.3,
#  29.1,
#  32.2,
#  24.3,
#  29.0,
#  29.5,
#  26.3,
#  28.7,
#  29.0,
#  31.3,
#  28.2,
#  26.5,
#  27.0,
#  24.2,
#  31.2,
#  29.1,
#  30.1,
#  26.2,
#  33.0,
#  29.0,
#  29.9,
#  29.6,
#  29.0,
#  26.7,
#  29.3,
#  27.7,
#  27.9,
#  28.1,
#  29.7,
#  28.3,
# ...

# %%
print(f"La moyenne du premier échantillon est : {moyenne_echantillons[0]} et "
     f"l'écart type est : {ecart_type_echantillons[0]}.")
# Out:
# La moyenne du premier échantillon est : 53.9 et l'écart type est : 21.6.

# %% [markdown]
# <a id='question7'></a>
# # <div style=" background-color:#002F49; color:white; padding: 12px; line-height: 1.5;">8. | Question n°07</div>

# %% [markdown]
# <div style="font-family: Segoe UI; font-size: 16px; line-height: 2; color: #000000; text-align: justify">
#
# <span style="background-color: #F6CECE; color: #000000;"><b>
# Calculez la moyenne des moyennes d'échantillons et la moyenne des écart type des échantillons. Comparez-les à la moyenne et à l'écart type de l'ensemble de la classe. </b></span>
# </div>

# %%
moyenne_moyenne_echantillons = np.mean(moyenne_echantillons).round(1)
print(f"La moyenne des moyennes des échantillons est : {moyenne_moyenne_echantillons}.")
# Out:
# La moyenne des moyennes des échantillons est : 51.6.

# %%
print(f"{moyenne}")
# Out:
# 51.0

# %% [markdown]
# <div style="font-family: Segoe UI; line-height: 2; color: #000000; text-align: justify">
#
# La moyenne des moyennes des échantillons est égale à 51.6. Ce qui est très proche de <span style="background-color: #F6CECE; color: #000000;"><b>la moyenne réelle qui est égale à 51.0.</b></span>
# </div>

# %%
moyenne_ecart_type_echantillons = np.mean(ecart_type_echantillons).round(1)
print(f"La moyenne des écarts types des échantillons est : {moyenne_ecart_type_echantillons}.")
# Out:
# La moyenne des écarts types des échantillons est : 28.7.

# %%
print(f"{ecart_type}")
# Out:
# 29.3

# %% [markdown]
# <div style="font-family: Segoe UI; line-height: 2; color: #000000; text-align: justify">
#
# La moyenne des écarts types des échantillons est égale à 28.7. Ce qui est très proche de <span style="background-color: #F6CECE; color: #000000;"><b>l'écart type réel qui est égal à 29.3.</b></span>
# </div>

# %% [markdown]
# <a id='question8'></a>
# # <div style=" background-color:#002F49; color:white; padding: 12px; line-height: 1.5;">9. | Question n°08</div>

# %% [markdown]
# <div style="font-family: Segoe UI; font-size: 16px; line-height: 2; color: #000000; text-align: justify">
#
# <span style="background-color: #F6CECE; color: #000000;"><b>
# Tracez un histogramme des moyennes d'échantillons. Comparez visuellement cette distribution à une distribution normale.</b></span>
# </div>

# %%
plt.figure(figsize=(12,5), dpi = 200)

plt.hist(moyenne_echantillons, bins = 30, density = False, alpha = 0.7, label = "Échantillons")

plt.title("Distribution des moyennes de 1 000 échantillons")
plt.xlabel("Notes")
plt.ylabel("Fréquence")
plt.legend()
plt.show()

# %%
#Taille de l'image
plt.figure(figsize=(12,5), dpi = 200)

plt.hist(notes, bins = 50, density = False, alpha = 0.7, label = "Population")

#Légende
plt.title("Distribution des notes dans la population")
plt.xlabel("Notes")
plt.ylabel("Fréquence")
plt.legend()
plt.show()

# %% [markdown]
# <div style="font-family: Segoe UI; line-height: 2; color: #000000; text-align: justify">
#
# Nous observons que la distribution des moyennes des échantillons suit une <span style="background-color: #F6CECE; color: #000000;"><b>distribution normale</b></span> même si la population ne suit pas la loi normale.
# </div>

# %% [markdown]
# <a id='question9'></a>
# # <div style=" background-color:#002F49; color:white; padding: 12px; line-height: 1.5;">10. | Question n°09</div>

# %% [markdown]
# <div style="font-family: Segoe UI; font-size: 16px; line-height: 2; color: #000000; text-align: justify">
#
# <span style="background-color: #F6CECE; color: #000000;"><b>
# Calculez l’espérance et l’erreur type de ce processus aléatoire.</b></span>
# </div>

# %% [markdown]
# <div style="font-family: Segoe UI; line-height: 2; color: #000000; text-align: justify">
#
# <u>L’espérance de la somme obtenue d’un processus aléatoire est :</u>
#
# $$\text{Moyenne de la boîte} \times \text{Nombre de tirages}$$
# </div>

# %% [markdown]
# <div style="font-family: Segoe UI; line-height: 2; color: #000000; text-align: justify">
#
# <span style="background-color: #F6CECE; color: #000000;"><b>L’espérance de la moyenne obtenue est égale à la moyenne de la boîte.</b></span>
#
#
# La moyenne de la boîte est égale à 51.0. L’espérance prévoit dans un échantillon, <span style="background-color: #F6CECE; color: #000000;"><b>il devrait y avoir une note moyenne de 51 sur 100.</b></span>
#
# </div>

# %% [markdown]
# <div style="font-family: Segoe UI; line-height: 2; color: #000000; text-align: justify">
#
#
# <u>L’erreur type pour la somme d’un processus aléatoire est égale à :</u>
#
# $$\sqrt{\text{Nombre de tirages}} \times \text{Écart type}$$
# </div>

# %% [markdown]
# <div style="font-family: Segoe UI; line-height: 2; color: #000000; text-align: justify">
#
# <u>Pour la moyenne d’un échantillon :</u>
#
# $$\frac{\text{Écart type}}{\sqrt{\text{Nombre de tirages}}}$$
# </div>

# %%
erreur_type = ecart_type / np.sqrt(30)
print(f"L'erreur type est égale à : {erreur_type.round(2)}.")
# Out:
# L'erreur type est égale à : 5.35.

# %% [markdown]
# <div style="font-family: Segoe UI; line-height: 2; color: #000000; text-align: justify">
#
# <span style="background-color: #F6CECE; color: #000000;"><b>L’espérance prévoit que dans un échantillon, la note moyenne est de 51.0, à plus ou moins 5.34 près.</b></span>
#
# </div>

# %%
print(f"La moyenne des moyennes des échantillons est : {moyenne_moyenne_echantillons}.")
# Out:
# La moyenne des moyennes des échantillons est : 51.6.

# %%
print(f"L'écart type des moyennes des échantillons est : {np.std(moyenne_echantillons).round(2)}.")
# Out:
# L'écart type des moyennes des échantillons est : 5.44.

# %% [markdown]
# <a id='question10'></a>
# # <div style=" background-color:#002F49; color:white; padding: 12px; line-height: 1.5;">11. | Question n°10</div>

# %% [markdown]
# <div style="font-family: Segoe UI; font-size: 16px; line-height: 2; color: #000000; text-align: justify">
#
# <span style="background-color: #F6CECE; color: #000000;"><b>
# Calculez la probabilité que la moyenne d'un échantillon de 30 étudiants soit supérieure à 60 points, en utilisant le z score et en utilisant la distribution des moyennes d’échantillons que vous avez obtenus.</b></span>
# </div>

# %% [markdown]
# ## <div style=" background-color: #D72729; color:white; padding: 10px; line-height: 1.5;"> Approche empirique
# </div>

# %%
moyenne_echantillons = np.array(moyenne_echantillons)

# %%
moyenne_sup60 = len(moyenne_echantillons[moyenne_echantillons >= 60])

# %%
len(moyenne_echantillons)
# Out:
# 1000

# %%
(moyenne_sup60 / 1_000)*100
# Out:
# 5.4

# %% [markdown]
# <div style="font-family: Segoe UI; line-height: 2; color: #000000; text-align: justify">
#
# <span style="background-color: #F6CECE; color: #000000;"><b>5.4% des moyennes des échantillons sont supérieurs à 60.</b></span> C'est-à-dire que la probabilité d'obtenir un échantillon avec une moyenne supérieure à 60 est de 5.4%.
#
# </div>

# %% [markdown]
# ## <div style=" background-color: #D72729; color:white; padding: 10px; line-height: 1.5;"> Approche théorique
# </div>

# %% [markdown]
# <div style="font-family: Segoe UI; line-height: 2; color: #000000; text-align: justify">
#
# Comme la distribution des moyennes des échantillons suit la loi normale, nous pouvons utiliser le z score.
#
# </div>

# %% [markdown]
# <div style="font-family: Segoe UI; line-height: 2; color: #000000; text-align: justify">
#
# Pour calculer la probabilité que dans un échantillon la moyenne de 30 personnes soit supérieure à 60, nous calculons le z score.
# </div>

# %% [markdown]
# <div style="font-family: Segoe UI; line-height: 2; color: #000000; text-align: justify">
#
#
# <u>De combien d’erreur type la valeur 60 diffère de l’espérance ?</u>
#
# $$\frac{(X - \text{Espérance})}{\text{Erreur type}}$$
# </div>

# %%
z_score = (60-moyenne) / erreur_type
print(f"{z_score.round(2)}")
# Out:
# 1.68

# %% [markdown]
# <div style="font-family: Segoe UI; line-height: 2; color: #000000; text-align: justify">
# 60 se situe à <span style="background-color: #F6CECE; color: #000000;"><b>1.68 erreur type</b></span> de l’espérance.
# </div>

# %% [markdown]
# <center><img
# src="https://conversion-uplift.co.uk/wp-content/uploads/2016/10/Z-Score-Table-e1662377674110.jpg"
#              style="width:40%;height:40%;">
# </center>

# %% [markdown]
# <div style="font-family: Segoe UI; line-height: 2; color: #000000; text-align: justify">
# <span style="background-color: #F6CECE; color: #000000;"><b>45,35%</b></span> des échantillons aléatoires sont compris entre 1.68 erreur type et la moyenne, soit entre 51 et 60.
# </div>

# %% [markdown]
# <div style="font-family: Segoe UI; line-height: 2; color: #000000; text-align: justify">
# <span style="background-color: #F6CECE; color: #000000;"><b>4.65% des échantillons aléatoires sont supérieurs à 60. </b></span>
# </div>

# %% [markdown]
# <div style="font-family: Segoe UI; line-height: 2; color: #000000; text-align: justify">
# La probabilité que dans un échantillon la moyenne soit supérieure à 60 est de 4.65%.
# </div>

# %% [markdown]
# <div style="font-family: Segoe UI; line-height: 2; color: #000000; text-align: justify">
# <span style="background-color: #F6CECE; color: #000000;"><b>L’approche empirique est extrêmement proche de l’approche théorique,</b></span> et si nous augmentons le nombre d’échantillons, par exemple la distribution des moyennes de 10 000 échantillons, l’approche empirique se rapprochera encore plus de la théorie.
# </div>
